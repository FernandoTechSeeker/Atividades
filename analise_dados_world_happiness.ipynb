# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoTechSeeker/Atividades/blob/main/analise_dados_world_happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Projeto Final – Relatório de Análise de Dados
#
# **Introdução Geral**
#
# Neste projeto, realizei diversas etapas de análise de dados, desde a criação de um pequeno programa de tabuada até a análise de um dataset público e a expansão da análise com o World Happiness Report.
#
# O projeto será estruturado em 5 partes:
#
# * 1️⃣ Cálculo da Tabuada (Implementação de lógica básica em Python)
# * 2️⃣ Escolha e Análise de um Dataset Público (Carregar e explorar um conjunto de dados)
# * 3️⃣ Expansão da Análise com o World Happiness Report (Junção de múltiplos datasets)
# * 4️⃣ Visualização de Dados – Gráficos (Criação de gráficos com Matplotlib e Seaborn)
# * 5️⃣ Entrega Final (Notebook organizado e vídeo explicativo)

# %% [markdown]
# ## 1️⃣Cálculo da Tabuada
#  📌 Objetivo: Criar uma função que exiba a tabuada de um número de 1 a 10.
#
# 📌 Passos:
# - ✔ Criar uma função calcular_tabuada(numero: int).
# - ✔ Validar se o número está no intervalo de 1 a 10.
# - ✔ Exibir a tabuada do número informado.
# - ✔ Se o número for inválido, exibir uma mensagem de erro.
# - ✔ Melhorias sugeridas: Criar um loop para novas tentativas e melhorar a formatação da saída.

# %%
# Função para calcular e exibir a tabuada com tipagem explícita
def calcular_tabuada(numero: int) -> None:
    """
    Função que exibe a tabuada de um número entre 1 e 10.

    Parâmetros:
    numero (int): Número para calcular a tabuada.

    Retorno:
    Exibe a tabuada do número escolhido ou uma mensagem de erro se o número estiver fora do intervalo.
    """
    print("\n" + "=" * 25)
    print(f"📌 Tabuada do {numero}".center(25))
    print("=" * 25)

    for i in range(1, 11):
        print(f"{numero} x {i:2} = {numero * i:3}")  # Formatação para alinhar os resultados

    print("=" * 25, "\n")

# Loop para permitir novas tentativas caso o usuário insira um valor inválido
while True:
    try:
        num = int(input("🔹 Digite um número entre 1 e 10 para ver a tabuada (ou 0 para sair): "))

        if num == 0:
            print("✅ Saindo do programa. Até mais!")
            break  # Encerra o loop se o usuário digitar 0

        if 1 <= num <= 10:
            calcular_tabuada(num)  # Chamada da função para exibir a tabuada
        else:
            print("❌ Erro: O número deve estar entre 1 e 10. Tente novamente.")

    except ValueError:
        print("❌ Erro: Por favor, insira um número inteiro válido.")
# Out:
# ...
#       📌 Tabuada do 1
# ...
# 1 x  1 =   1
# 1 x  2 =   2
# 1 x  3 =   3
# 1 x  4 =   4
# 1 x  5 =   5
# 1 x  6 =   6
# 1 x  7 =   7
# 1 x  8 =   8
# 1 x  9 =   9
# 1 x 10 =  10
# ...
#
#
# ...
#       📌 Tabuada do 5
# ...
# 5 x  1 =   5
# 5 x  2 =  10
# 5 x  3 =  15
# 5 x  4 =  20
# 5 x  5 =  25
# 5 x  6 =  30
# 5 x  7 =  35
# 5 x  8 =  40
# 5 x  9 =  45
# 5 x 10 =  50
# ...
#
# ❌ Erro: O número deve estar entre 1 e 10. Tente novamente.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1389768c2691> in <cell line: 0>()
#      22 while True:
#      23     try:
# ---> 24         num = int(input("🔹 Digite um número entre 1 e 10 para ver a tabuada (ou 0 para sair): "))
#      25
#      26         if num == 0:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %% [markdown]
# ##2️⃣ Escolha e Análise de um Dataset Público
#
# Dataset Escolhido: **World Happiness Report 2022**
#
# - ✔ Descrição: Dados sobre felicidade global, incluindo PIB per capita, suporte social e expectativa de vida.
# - ✔ Analise estatísticas dos países e comparações entre anos.
# - ✔ Visualizar informações iniciais com .info() e .describe().
# - ✔ Selecionar colunas relevantes e discutir os dados.

# %%
# 📌 Importando a biblioteca Pandas para manipulação de dados
import pandas as pd

# 📌 Carregando o dataset de Felicidade Mundial 2022
# Este dataset contém informações sobre diversos países e seus índices de felicidade.
df_happiness = pd.read_csv("World_Happiness_2022.csv")

# 📌 Exibindo as primeiras linhas do dataset para entender sua estrutura
# Isso nos ajuda a visualizar como os dados estão organizados.
print("🔹 Primeiras 5 linhas do dataset:")
display(df_happiness.head())

# 📌 Exibindo informações gerais do dataset
# Aqui verificamos quantas colunas temos, o tipo de dados e se há valores nulos.
print("\n🔹 Informações gerais do dataset:")
df_happiness.info()

# 📌 Exibindo estatísticas descritivas
# Estatísticas como média, desvio padrão, valores mínimos e máximos são úteis para entender os dados.
print("\n🔹 Estatísticas gerais do dataset:")
display(df_happiness.describe())

# 📌 Selecionando colunas mais relevantes para análise
# Como o dataset pode ter muitas colunas, escolhemos as mais importantes para esta análise.
colunas_relevantes = ['Country', 'Happiness score', 'Explained by: GDP per capita',
                      'Explained by: Social support', 'Explained by: Healthy life expectancy']

# 📌 Filtrando o DataFrame com as colunas corretas
# Aqui criamos um novo DataFrame contendo apenas as colunas selecionadas.
df_happiness_filtrado = df_happiness[colunas_relevantes]

# 📌 Exibindo dataset filtrado
# Agora, mostramos as primeiras linhas desse novo DataFrame para verificar se a seleção foi feita corretamente.
print("🔹 Dataset filtrado com colunas relevantes:")
display(df_happiness_filtrado.head())
# Out:
# 🔹 Primeiras 5 linhas do dataset:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %% [markdown]
# ##3️⃣ Expansão da Análise com o World Happiness Report
# Nesta etapa, daremos continuidade à análise do Relatório Mundial da Felicidade, incorporando os dados do ano de 2020 ao conjunto já utilizado (2019 e 2022). O objetivo é unificar essas informações para identificar padrões e variações na felicidade global ao longo do tempo.
#
# 🔹 Objetivos desta etapa:
# - ✔ Carregar os dados do ano de 2020 e verificar sua estrutura.
# - ✔ Tratar e limpar os dados, garantindo que estejam padronizados para junção.
# - ✔ Unificar os datasets de 2019, 2020 e 2022 para facilitar a análise comparativa.
# - ✔ Utilizar os métodos do Pandas (merge, concat) para consolidar os dados corretamente.
# - ✔ Exibir os dados finais e estatísticas para verificar padrões e tendências.

# %%
# 📌 Importando a biblioteca Pandas
import pandas as pd

# 📌 Carregando os datasets de Felicidade Mundial para os anos de 2019, 2020 e 2022
df_2019 = pd.read_csv("World_Happiness_2019.csv")
df_2020 = pd.read_csv("World_Happiness_2020.csv")
df_2022 = pd.read_csv("World_Happiness_2022.csv")

# 📌 Exibir as primeiras linhas de cada dataset para entender sua estrutura
print("🔹 Primeiras linhas do dataset de 2019:")
display(df_2019.head())

print("\n🔹 Primeiras linhas do dataset de 2020:")
display(df_2020.head())

print("\n🔹 Primeiras linhas do dataset de 2022:")
display(df_2022.head())

# 📌 Exibir informações gerais dos datasets para identificar colunas e valores nulos
print("🔹 Informações do Dataset 2019:")
df_2019.info()

print("\n🔹 Informações do Dataset 2020:")
df_2020.info()

print("\n🔹 Informações do Dataset 2022:")
df_2022.info()

# 📌 Selecionando colunas mais relevantes para análise
# Como os datasets possuem colunas diferentes, ajustamos os nomes conforme necessário
colunas_relevantes_2019 = ['Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy']
colunas_relevantes_2020 = ['Country name', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy']
colunas_relevantes_2022 = ['Country', 'Happiness score', 'Explained by: GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy']

# 📌 Renomeando colunas para manter um padrão único antes da união dos datasets
df_2019 = df_2019[colunas_relevantes_2019].rename(columns={
    'Country or region': 'Country',
    'Score': 'Happiness Score',
    'GDP per capita': 'GDP per capita',
    'Social support': 'Social Support',
    'Healthy life expectancy': 'Healthy Life Expectancy'
})

df_2020 = df_2020[colunas_relevantes_2020].rename(columns={
    'Country name': 'Country',
    'Ladder score': 'Happiness Score',
    'Logged GDP per capita': 'GDP per capita',
    'Social support': 'Social Support',
    'Healthy life expectancy': 'Healthy Life Expectancy'
})

df_2022 = df_2022[colunas_relevantes_2022].rename(columns={
    'Country': 'Country',
    'Happiness score': 'Happiness Score',
    'Explained by: GDP per capita': 'GDP per capita',
    'Explained by: Social support': 'Social Support',
    'Explained by: Healthy life expectancy': 'Healthy Life Expectancy'
})

# 📌 Adicionando a informação do ano a cada dataset
df_2019['Year'] = 2019
df_2020['Year'] = 2020
df_2022['Year'] = 2022

# 📌 Unindo os datasets para análise completa
df_completo = pd.concat([df_2019, df_2020, df_2022], ignore_index=True)

# 📌 Exibir os primeiros dados combinados
print("🔹 Dados combinados após a unificação:")
display(df_completo.head(1000))

# 📌 Exibir estatísticas descritivas dos dados combinados
print("\n🔹 Estatísticas dos Dados Combinados:")
display(df_completo.describe())

# 📌 Exibir a quantidade total de países analisados
print("\n🔹 Quantidade de países analisados:", df_completo['Country'].nunique())
# Out:
# 🔹 Primeiras linhas do dataset de 2019:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# ...

# %% [markdown]
# ##4️⃣ Visualização de Dados – Gráficos
# Nesta seção, iremos criar e interpretar gráficos baseados nos dados do World Happiness Report para identificar padrões e insights relevantes. Utilizaremos as bibliotecas Matplotlib e Seaborn para gerar as visualizações.
#
# Objetivos desta etapa:
# - ✔Criar três gráficos para representar os dados
# - ✔ Identificar padrões e tendências através da visualização
# - ✔ Explicar os insights obtidos a partir dos gráficos

# %%
# 📌 Importando bibliotecas essenciais para análise e visualização de dados
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração do estilo dos gráficos para uma melhor visualização
sns.set_style("whitegrid")

# %% [markdown]
# Verificamos anteriormente que a unificação dos datasets funcionou corretamente, então agora podemos prosseguir diretamente para a análise.

# %%
# 🔹 Verificar as primeiras linhas do dataset consolidado para garantir que os dados estão corretos
print("🔹 Primeiras linhas do dataset consolidado:")
display(df_completo.head())

# 🔹 Exibir estatísticas descritivas do dataset consolidado
print("\n🔹 Estatísticas descritivas dos dados combinados:")
display(df_completo.describe())

# 🔹 Exibir a quantidade de países analisados
print("\n🔹 Quantidade total de países analisados:", df_completo["Country"].nunique())
# Out:
# 🔹 Primeiras linhas do dataset consolidado:
#        Country  Happiness Score  GDP per capita  Social Support  \
# 0      Finland            7.769           1.340           1.587
# 1      Denmark            7.600           1.383           1.573
# 2       Norway            7.554           1.488           1.582
# 3      Iceland            7.494           1.380           1.624
# 4  Netherlands            7.488           1.396           1.522
#
#    Healthy Life Expectancy  Year
# 0                    0.986  2019
# 1                    0.996  2019
# 2                    1.028  2019
# 3                    1.026  2019
# 4                    0.999  2019
# 🔹 Estatísticas descritivas dos dados combinados:
#        Happiness Score  GDP per capita  Social Support  \
# count       455.000000      455.000000      455.000000
# mean          5.476340        3.888727        0.977067
# std           1.103653        3.934555        0.300328
# min           2.404000        0.000000        0.000000
# ...

# %% [markdown]
# Agora vamos criar três gráficos diferentes para analisar a evolução dos índices de felicidade.
#
# ###1️⃣ Gráfico de Barras – Top 10 países mais felizes em 2019, 2020, 2022.

# %%
# Filtrando os 10 países mais felizes de cada ano
top_10_2019 = df_completo[df_completo["Year"] == 2019].nlargest(10, "Happiness Score")
top_10_2020 = df_completo[df_completo["Year"] == 2020].nlargest(10, "Happiness Score")
top_10_2022 = df_completo[df_completo["Year"] == 2022].nlargest(10, "Happiness Score")

# Concatenando os três anos em um único DataFrame
df_top_10 = pd.concat([top_10_2019, top_10_2020, top_10_2022])

# Criando gráfico de barras agrupado
plt.figure(figsize=(12, 6))
sns.barplot(data=df_top_10, x="Country", y="Happiness Score", hue="Year", palette="viridis")

# Adicionando títulos e rótulos
plt.title("📊 Comparação dos 10 Países Mais Felizes (2019, 2020, 2022)", fontsize=14)
plt.xlabel("Países")
plt.ylabel("Índice de Felicidade")
plt.xticks(rotation=45)  # Inclinar os nomes dos países para melhor leitura
plt.legend(title="Ano")  # Legenda indicando cada ano

# Exibindo gráfico
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##2️⃣ Gráfico de Linha – Evolução da Felicidade de Alguns Países de 2019, 2020, 2022.

# %%
# Selecionar países específicos para análise da evolução da felicidade
paises_selecionados = ["Finland", "Denmark", "Norway", "Iceland", "Switzerland"]

# Filtrar o DataFrame apenas para esses países
df_paises = df_completo[df_completo["Country"].isin(paises_selecionados)]

# Criar o gráfico de linha
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_paises, x="Year", y="Happiness Score", hue="Country", marker="o", linewidth=2)

# Adicionar títulos e rótulos
plt.title("📈 Evolução do Índice de Felicidade (2019-2022)", fontsize=14)
plt.xlabel("Ano")
plt.ylabel("Índice de Felicidade")
plt.xticks([2019, 2020, 2022])  # Garantir que apenas os anos analisados apareçam
plt.legend(title="Países")

# Exibir gráfico
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##3️⃣ Gráfico de Dispersão – PIB per Capita x Felicidade

# %%
# Criando o gráfico de dispersão (scatter plot)
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df_completo, x="GDP per capita", y="Happiness Score", hue="Year", palette="coolwarm", alpha=0.7)

# Adicionando títulos e rótulos
plt.title("💰 Relação entre PIB per Capita e Felicidade", fontsize=14)
plt.xlabel("PIB per Capita")
plt.ylabel("Índice de Felicidade")

# Exibindo gráfico
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
